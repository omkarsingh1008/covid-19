# %%
# importing required modules 
import PyPDF2 
  
# creating a pdf file object 
pdfFileObj = open('DistrictWiseList324.pdf', 'rb') 
  
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
  
# printing number of pages in pdf file 
print(pdfReader.numPages) 
  
# creating a page object 
pageObj = pdfReader.getPage(0) 
data=pageObj.extractText()
  
# extracting text from page 
print(pageObj.extractText())
# Out:
# 4
# State/District wise details of Positive cases of Covid19
#
# State
#
# No of
# Dist
#
# District
#
# No of Positive
# cases
#
# A&N Islands
#
# 1
# #
#
#
# 1
# *
#
# Andhra Pradesh
#
# 8
# #
#
# Chitoor
#
# 1
#
# East Godavari
#
# 2
#
# Guntur
#
# 1
#
# Krishna
#
# 1
#
# Nellore
#
# 1
#
# Prakasam
#
# 1
#
# Vijayawada,Krishna
#
# 1
#
# Vizag
#
# 3
#
#
# 1
# *
#
# BIHAR
#
# 2
# #
#
# MUNGER
#
# 2
#
# PATNA
#
# 3
#
#
# 1
# *
#
# Chandigarh
#
# 1
#
# Chandigarh
#
# 7
#
# Chhattisgarh
#
# 2
# #
#
# Raipur
#
# 2
#
# Rajnandgaon
#
# 1
#
#
# 3
# *
#
# Delhi
#
# 8
# #
#
# Central
#
# 3
#
# East Delhi
#
# 5
#
# North Delhi
#
# 4
#
# North East
#
# 5
#
# North West
#
# 5
#
# South Delhi
#
# 5
#
# South West
#
# 3
#
# West Delhi
#
# 5
#
#
# 1
# *
#
# Goa
#
#
# #
#
#
# 3
# *
#
# Gujarat
#
# 6
# #
#
# Ahmedabad
#
# 14
#
# Gandhinagar
#
# 7
#
# Kutch
#
# 1
#
# Rajkot
#
# 3
#
# Surat
#
# 6
#
# Vadodara
#
# 7
#
#
# 5
# *
#
# Haryana
#
# 6
#
# Faridabad
#
# 1
#
# Gurugram
#
# 24
#
# Palwal
#
# 1
#
# Panchkula
#
# 1
#
# Panipat
#
# 2
#
# Sonipat
#
# 1
#
# Himachal Pradesh
#
# 1
#
# Kangra
#
# 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('DistrictWiseList324.csv')

# %%
data['State/District wise details of Positive cases of Covid19']
# Out:
# 0                                                    NaN
# 1                                                  State
# 2                                                    NaN
# 3                                            A&N Islands
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                        Andhra Pradesh
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                BIHAR
# 15                                                   NaN
# 16                                           Chandigarh
# 17                                                   NaN
# 18                                         Chhattisgarh
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                Delhi
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                  Goa
#                              ...
# 131                                                  NaN
# 132                                                  NaN
# 133                                           Telangana
# 134                                                  NaN
# 135                                                  NaN
# 136                                                  NaN
# 137                                                  NaN
# 138                                                  NaN
# 139                                                  NaN
# 140                                                  NaN
# 141                                                  NaN
# 142                                                  NaN
# 143                                       Uttar Pradesh
# 144                                                  NaN
# 145                                                  NaN
# 146                                                  NaN
# 147                                                  NaN
# 148                                                  NaN
# 149                                                  NaN
# 150                                         Uttarakhand
# 151                                                  NaN
# 152                                                  NaN
# 153                                                  NaN
# 154                                         West Bengal
# 155                                                  NaN
# 156                                                  NaN
# 157                                               Total
# 158                       Total District affected - 132
# 159    # Likely to change once districts of all known...
# 160    * The details of the districts are being ascer...
# Name: State/District wise details of Positive cases of Covid19, Length: 161, dtype: object

# %%
data['Unnamed: 1']
# Out:
# 0      No of
# 1        NaN
# 2      Dist
# 3        1#
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        8#
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       2#
# 15       NaN
# 16         1
# 17       NaN
# 18       2#
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       8#
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29        #
#        ...
# 131      NaN
# 132      NaN
# 133        8
# 134      NaN
# 135      NaN
# 136      NaN
# 137      NaN
# 138      NaN
# 139      NaN
# 140      NaN
# 141      NaN
# 142      NaN
# 143       11
# 144      NaN
# 145      NaN
# 146      NaN
# 147      NaN
# 148      NaN
# 149      NaN
# 150        2
# 151      NaN
# 152      NaN
# 153      NaN
# 154      3#
# 155      NaN
# 156      NaN
# 157    132#
# 158      NaN
# 159      NaN
# 160      NaN
# Name: Unnamed: 1, Length: 161, dtype: object

# %%
data[data['Unnamed: 2']=='pali']
# Out:
# Empty DataFrame
# Columns: [State/District wise details of Positive cases of Covid19, Unnamed: 1, Unnamed: 2, Unnamed: 3]
# Index: []

# %%
data['Unnamed: 3']
# Out:
# 0      No of Positive
# 1                 NaN
# 2              cases
# 3                 1*
# 4                   1
# 5                   2
# 6                   1
# 7                   1
# 8                   1
# 9                   1
# 10                  1
# 11                  3
# 12                1*
# 13                  2
# 14                  3
# 15                1*
# 16                  7
# 17                  2
# 18                  1
# 19                3*
# 20                  3
# 21                  5
# 22                  4
# 23                  5
# 24                  5
# 25                  5
# 26                  3
# 27                  5
# 28                1*
# 29                3*
#             ...
# 131                27
# 132                 1
# 133                 1
# 134                 1
# 135                 3
# 136                 7
# 137                 1
# 138                 8
# 139                14
# 140                 3
# 141                 1
# 142                 1
# 143                 1
# 144                 8
# 145                 1
# 146                 2
# 147                 1
# 148                 1
# 149                 4
# 150               NaN
# 151                 1
# 152                 6
# 153                 2
# 154               NaN
# 155                 1
# 156               1*
# 157               724
# 158               NaN
# 159               NaN
# 160               NaN
# Name: Unnamed: 3, Length: 161, dtype: object

# %%
data[data['State/District wise details of Positive cases of Covid19']=='Rajasthan']
# Out:
#     State/District wise details of Positive cases of Covid19 Unnamed: 1  \
# 113                                          Rajasthan              7#
#
#     Unnamed: 2 Unnamed: 3
# 113        NaN        NaN

# %%
data
# Out:
#     State/District wise details of Positive cases of Covid19 Unnamed: 1  \
# 0                                                  NaN            No of
# 1                                                State              NaN
# 2                                                  NaN            Dist
# 3                                          A&N Islands              1#
# 4                                                  NaN              NaN
# 5                                                  NaN              NaN
# 6                                                  NaN              NaN
# 7                                                  NaN              NaN
# 8                                      Andhra Pradesh               8#
# 9                                                  NaN              NaN
# 10                                                 NaN              NaN
# 11                                                 NaN              NaN
# 12                                                 NaN              NaN
# 13                                                 NaN              NaN
# 14                                              BIHAR               2#
# 15                                                 NaN              NaN
# 16                                         Chandigarh                 1
# 17                                                 NaN              NaN
# 18                                       Chhattisgarh               2#
# 19                                                 NaN              NaN
# 20                                                 NaN              NaN
# 21                                                 NaN              NaN
# 22                                                 NaN              NaN
# 23                                                 NaN              NaN
# 24                                              Delhi               8#
# 25                                                 NaN              NaN
# 26                                                 NaN              NaN
# 27                                                 NaN              NaN
# 28                                                 NaN              NaN
# 29                                                Goa                #
# ..                                                 ...              ...
# 131                                                NaN              NaN
# 132                                                NaN              NaN
# 133                                         Telangana                 8
# 134                                                NaN              NaN
# 135                                                NaN              NaN
# 136                                                NaN              NaN
# 137                                                NaN              NaN
# 138                                                NaN              NaN
# 139                                                NaN              NaN
# 140                                                NaN              NaN
# 141                                                NaN              NaN
# 142                                                NaN              NaN
# 143                                     Uttar Pradesh                11
# 144                                                NaN              NaN
# 145                                                NaN              NaN
# 146                                                NaN              NaN
# 147                                                NaN              NaN
# 148                                                NaN              NaN
# 149                                                NaN              NaN
# 150                                       Uttarakhand                 2
# 151                                                NaN              NaN
# 152                                                NaN              NaN
# 153                                                NaN              NaN
# 154                                       West Bengal               3#
# 155                                                NaN              NaN
# 156                                                NaN              NaN
# 157                                             Total             132#
# 158                     Total District affected - 132               NaN
# 159  # Likely to change once districts of all known...              NaN
# 160  * The details of the districts are being ascer...              NaN
#
#               Unnamed: 2      Unnamed: 3
# 0                    NaN  No of Positive
# 1               District             NaN
# 2                    NaN          cases
# 3                    NaN             1*
# 4               Chitoor                1
# 5         East Godavari                2
# 6                Guntur                1
# 7               Krishna                1
# 8               Nellore                1
# 9              Prakasam                1
# 10   Vijayawada,Krishna                1
# 11                Vizag                3
# 12                   NaN             1*
# 13               MUNGER                2
# 14                PATNA                3
# 15                   NaN             1*
# 16           Chandigarh                7
# 17               Raipur                2
# 18          Rajnandgaon                1
# 19                   NaN             3*
# 20              Central                3
# 21           East Delhi                5
# 22          North Delhi                4
# 23           North East                5
# 24           North West                5
# 25          South Delhi                5
# 26            South West               3
# 27            West Delhi               5
# 28                   NaN             1*
# 29                   NaN             3*
# ..                   ...             ...
# 131           Hyderabad               27
# 132          Karimnagar                1
# 133             Madchal                1
# 134        Mahboobnagar                1
# 135             Medchal                3
# 136         Ranga Reddy                7
# 137        Warangal (U)                1
# 138                Agra                8
# 139            GB Nagar               14
# 140           Ghaziabad                3
# 141             Jaunpur                1
# 142              Kanpur                1
# 143     Lakhimpur Kheri                1
# 144             Lucknow                8
# 145            Moradabd                1
# 146           Philibhit                2
# 147              Shamli                1
# 148            Varanasi                1
# 149            Dehradun                4
# 150                  NaN             NaN
# 151       Pauri Garhwal                1
# 152             Kolkata                6
# 153    North 24 Pargana                2
# 154                  NaN             NaN
# 155    South 24 Pargana                1
# 156                  NaN             1*
# 157                  NaN             724
# 158                  NaN             NaN
# 159                  NaN             NaN
# 160                  NaN             NaN
#
# [161 rows x 4 columns]

# %%
import COVID19Py
covid19 = COVID19Py.COVID19()

# %%
location = covid19.getLocationByCountryCode('IN')

# %%
location
# Out:
# [{'id': 131,
#   'country': 'India',
#   'country_code': 'IN',
#   'country_population': 1173108018,
#   'province': '',
#   'last_updated': '2020-03-28T12:56:23.898742Z',
#   'coordinates': {'latitude': '21.0', 'longitude': '78.0'},
#   'latest': {'confirmed': 887, 'deaths': 20, 'recovered': 0}}]

# %%
data = covid19.getAll()

# %%
data['locations'][0]
# Out:
# {'id': 0,
#  'country': 'Afghanistan',
#  'country_code': 'AF',
#  'country_population': 29121286,
#  'province': '',
#  'last_updated': '2020-03-28T12:55:26.463304Z',
#  'coordinates': {'latitude': '33.0', 'longitude': '65.0'},
#  'latest': {'confirmed': 110, 'deaths': 4, 'recovered': 0}}

# %%
helps=pd.read_csv('coronvavirushelplinenumber (1).csv')

# %%
n=int(helps[helps['Name of the State']=='Goa']['Helpline Nos.'])

# %%
n
# Out:
# 104

# %%
covid_19=pd.read_csv('D:\\hackathon_Adhoc\\covid19-corona-virus-india-dataset\\complete.csv')
state=covid_19[covid_19['Name of State / UT']==citys['candidates'][0]]
covid_19=covid_19[covid_19['Name of State / UT']==citys['candidates'][0]['formatted_address'].split(',')[1][1:]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4093a709a397> in <module>
#       1 covid_19=pd.read_csv('D:\\hackathon_Adhoc\\covid19-corona-virus-india-dataset\\complete.csv')
# ----> 2 state=covid_19[covid_19['Name of State / UT']==citys['candidates'][0]]
#       3 covid_19=covid_19[covid_19['Name of State / UT']==citys['candidates'][0]['formatted_address'].split(',')[1][1:]]
#
# NameError: name 'citys' is not defined
